# %% [markdown]
# # Response to Jobs Report 2017
#
# http://www.businessinsider.com/trump-response-to-jobs-report-sean-spicer-2017-3

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## All Employees: Total Nonfarm Payrolls (PAYEMS)
#
# All Employees: Total Nonfarm, commonly known as Total Nonfarm Payroll, is a measure of the number of U.S. workers in the economy that excludes proprietors, private household employees, unpaid volunteers, farm employees, and the unincorporated self-employed. This measure accounts for approximately 80 percent of the workers who contribute to Gross Domestic Product (GDP).
#
# The data is available from the repository of the **FEDERAL RESERVE BANK OF ST. LOUIS - Economic Research** site   https://fred.stlouisfed.org/series/PAYEMS
#
# The source of the data is **United States Bureau of Labor Statistics** https://www.bls.gov/

# %%
PAYEMS = web.DataReader(["PAYEMS"], "fred", start=datetime.datetime(2000, 1, 1), end=datetime.datetime(2017, 3, 1))

# %% [markdown]
# ## "Fake before but very real now"
# **February 2017** Employment results looks very much like previous results... excluding our economic 2008 - 2010 issues

# %%
PAYEMS['PAYEMS_DIFF'] = PAYEMS.PAYEMS.diff()
#sns.tsplot(data=PAYEMS.PAYEMS_DIFF)
PAYEMS.PAYEMS_DIFF.plot()
plt.show()

PAYEMS['PAYEMS_PCT_DIFF'] = PAYEMS.PAYEMS_DIFF / PAYEMS.PAYEMS * 100
#sns.tsplot(data=PAYEMS.PAYEMS_PCT_DIFF)
PAYEMS.PAYEMS_PCT_DIFF.plot()
plt.show()

# %% [markdown]
# ## February Non-Farm Employment report for the Last Five Years
#
# 1. The Employment report for **February 2017** were good, but in line with the past five Februaries.
# 2. The expected additions for **February 2017** were 200K, a little understated when in February 2015 it was 238K and 237K for 2016.

# %%
FEB_PAYEMS = PAYEMS[(PAYEMS.index.month == 2) & (PAYEMS.index.year >= 1980)]
FEB_PAYEMS.tail(5)
# Out:
#             PAYEMS  PAYEMS_DIFF  PAYEMS_PCT_DIFF
# DATE
# 2013-02-01  135569        286.0         0.210963
# 2014-02-01  137715        151.0         0.109647
# 2015-02-01  140844        238.0         0.168981
# 2016-02-01  143448        237.0         0.165217
# 2017-02-01  145798        235.0         0.161182

# %% [markdown]
# ## February  Non-Farm Employment report since 1980
#
# Since the year 2000, there have been other years with better February Employment results

# %%
FEB_PAYEMS.PAYEMS_DIFF.plot()
plt.show()
